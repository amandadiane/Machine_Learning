# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

# %%
data = [0,1,1,2,3,4,4,4,5]

# %%
hist = plt.hist(data, bins=6)

# %%
import seaborn as sns
sns.set(color_codes=True)
ax = sns.kdeplot(data, bw=.1, kernel='gau', label='Bandwidth = .1')
ax = sns.kdeplot(data, bw=1, kernel='gau', label='Bandwidth = 1')
ax.set(xlim=(-2,7))
# Out:
# [(-2, 7)]
